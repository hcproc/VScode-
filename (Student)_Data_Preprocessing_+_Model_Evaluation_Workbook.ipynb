# %% [markdown]
# <a href="https://colab.research.google.com/github/hcproc/VScode-/blob/main/(Student)_Data_Preprocessing_%2B_Model_Evaluation_Workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Codes from ACE6233 Chapter 2 lecture slides

# %% [markdown]
# ## Source the Data, and Data Preprocessing

# %% [markdown]
# Read from a CSV file

# %%
from pandas import read_csv
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
df = read_csv('https://raw.githubusercontent.com/wooihaw/datasets/main/pima-indians-diabetes.data.csv', names=names)

# %% [markdown]
# `df` is a pandas DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# How many columns are there?

# %% [markdown]
# Statistical summary of the data

# %%
df.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %% [markdown]
# How many classes are there?

# %%
# Hint: df.groupby('class')

# %% [markdown]
# Separate the columns into **Features** & **Target**

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %% [markdown]
# Features in X, Target (Label) in y

# %%
type(array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2070400145.py in <cell line: 0>()
# ----> 1 type(array)
#
# NameError: name 'array' is not defined

# %%
type(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1535897611.py in <cell line: 0>()
# ----> 1 type(X)
#
# NameError: name 'X' is not defined

# %% [markdown]
# **How do we handle missing values?**

# %% [markdown]
# Example:

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'Age': [17, 23, 'x', 38, 54, 67, 32],
                  'Height': [160, 172, 150, 165, 163, 158, 175],
                  'Weight':[50, 68, 43, 52, 47, 49, 'x']})
print(df1)
# Out:
#   Age  Height Weight
# 0  17     160     50
# 1  23     172     68
# 2   x     150     43
# 3  38     165     52
# 4  54     163     47
# 5  67     158     49
# 6  32     175      x

# %%
df1.Age
# Out:
# 0    17
# 1    23
# 2     x
# 3    38
# 4    54
# 5    67
# 6    32
# Name: Age, dtype: object

# %%
type(df1.Age)
# Out:
# pandas.core.series.Series

# %%
df1.keys()
# Out:
# Index(['Age', 'Height', 'Weight'], dtype='object')

# %%
df1.values
# Out:
# array([[17, 160, 50],
#        [23, 172, 68],
#        ['x', 150, 43],
#        [38, 165, 52],
#        [54, 163, 47],
#        [67, 158, 49],
#        [32, 175, 'x']], dtype=object)

# %%
type(df1.values)
# Out:
# numpy.ndarray

# %% [markdown]
# Replace the missing values 'x' with NaN

# %%
# Hint: replace({'x': None}

# %%
df2 = df1.copy() # Keep a copy of df1 for latter use
df3 = df1.copy() # Keep a copy of df1 for latter use

# %% [markdown]
# **Method 1: Discard**
# Drop rows with NaN

# %%
# Hint: dropna()

# %% [markdown]
# **Method 2: Replace NaN with some value**

# %% [markdown]
# Replace NaN with the median value of the column

# %% [markdown]
# Replace NaN with the mean value of the column

# %%
print(df2)
# Out:
#   Age  Height Weight
# 0  17     160     50
# 1  23     172     68
# 2   x     150     43
# 3  38     165     52
# 4  54     163     47
# 5  67     158     49
# 6  32     175      x

# %% [markdown]
# **Feature Scaling**

# %% [markdown]
# Load the PIMA dataset

# %%
array = df.values

# %% [markdown]
# Separate the array into Features & Target

# %%
x=  array[:,:-1]
y = array[1,-1]

# %% [markdown]
# **1. Min-max scaling**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X)
scaledX = scaler.transform(X)

# %% [markdown]
# Check the min and max values of Column 1

# %%
a = min(scaledX[:,1])
b = max(scaledX[:,1])
print(f'Min value is {a},max value is {b}')
# Out:
# Min value is 0.0,max value is 1.0

# %% [markdown]
# **2. Standard scaling**

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
scaler.fit(X)
scaledX = scaler.transform(X)

# %% [markdown]
# Check the mean and standard deviation of Column 1

# %%
import numpy as np
a= np.mean(scaledX[:,1])
b = np.std(scaledX[:,1])
print(f'Mean value is {a},standard deviation is {b}')
# Out:
# Mean value is -9.25185853854297e-18,standard deviation is 1.0

# %% [markdown]
# **3. Robust Scaling**

# %%
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# Check the median and interquartile range (IQR) values

# %%
a = np.median(scaledX[:,1])
q75,q25 = np.percentile(scaledX[:,1],[75,25])
b = q75-q25
print(f'Median value is {a},IQR is {b}')
# Out:
# Median value is -0.12188771051207764,IQR is 1.291007244741765

# %% [markdown]
# **Handling Categorical Data**

# %% [markdown]
# Use `pandas` to encode **ordinal** and **nominal** categorical data

# %% [markdown]
# Example:

# %%
df0 = pd.DataFrame({'year':[2015, 2017, 2013, 2018, 2020],
                    'make':['Toyota', 'Honda', 'Perodua', 'Hyundai', 'Toyota'],
                    'engine':[1.5, 1.8, 1.3, 1.6, 1.8],
                    'review':['moderate', 'good', 'poor', 'moderate', 'good']})

# %%
df0
# Out:
#    year     make  engine    review
# 0  2015   Toyota     1.5  moderate
# 1  2017    Honda     1.8      good
# 2  2013  Perodua     1.3      poor
# 3  2018  Hyundai     1.6  moderate
# 4  2020   Toyota     1.8      good

# %% [markdown]
# Encode **ordinal** data

# %%
mapping = {'poor':1, 'moderate':2, 'good':3}

# %%
df0['review'] = df0['review'].map(mapping)
print(df0)
# Out:
#    year     make  engine  review
# 0  2015   Toyota     1.5       2
# 1  2017    Honda     1.8       3
# 2  2013  Perodua     1.3       1
# 3  2018  Hyundai     1.6       2
# 4  2020   Toyota     1.8       3

# %% [markdown]
# Encode **nominal** data using `get_dummies`

# %% [markdown]
# **Feature Engineering**

# %% [markdown]
# Load the PIMA dataset. Create 2 new features for it.

# %%
df['plas_pres'] = df['plas'] + df['pres'] # new feature 1

win_size = 3
df['mass_ave'] = df['mass'].rolling(win_size).mean() # new feature 2

# %% [markdown]
# Examine the first 5 rows

# %% [markdown]
# **Feature Selection**

# %% [markdown]
# Try with different methods: Select K Best, Select From Model, Recursive Feature Elimination (RFE), Dimensionality Reduction

# %%
from sklearn.feature_selection import SelectKBest, SelectFromModel, RFE

# %% [markdown]
# 1. **Univariate** Selection

# %% [markdown]
# Select 4 best features

# %%
# Hint: SelectKBest(k=4)

# %% [markdown]
# Show selected features

# %%
print([names[i] for i in range(len(names)-1) if selected[i]])

# %% [markdown]
# 2. **Model-based** Selection

# %% [markdown]
# First, choose a model. Here we choose the Random Forest Classifier.

# %%
from sklearn.ensemble import RandomForestClassifier
# Hint: SelectFromModel(RandomForestClassifier(),

# %% [markdown]
# Show selected features

# %%
print([names[i] for i in range(len(names)-1) if selected[i]])

# %% [markdown]
# 3.**Recursive Feature Elimination**

# %% [markdown]
# First, choose a model. Here we choose the Decision Tree Classifier.

# %%
from sklearn.tree import DecisionTreeClassifier
# Hint: RFE(DecisionTreeClassifier(),

# %% [markdown]
# Show selected features

# %%
print([names[i] for i in range(len(names)-1) if selected[i]])

# %% [markdown]
# 4. **Dimensionality Reduction**

# %% [markdown]
# Use Principal Component Analysis (PCA). Decide on the number of principal components, say 3.

# %%
from sklearn.decomposition import PCA
# Hint: PCA(n_components=3)

# %% [markdown]
# Summarize the selected components

# %%
print("Explained Variance: %s" % pca.explained_variance_ratio_)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# 1. **Hold-out Validation**

# %% [markdown]
# Do a Train-Test split. Decide on the Test size, say 20% of the dataset.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Choose a model, say K-Neighbors Classifier.

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %% [markdown]
# Training

# %% [markdown]
# Testing

# %% [markdown]
# What's the accuracy?

# %% [markdown]
# 2. **K-fold Cross-validation**

# %% [markdown]
# Do a 5-fold cross-validation

# %%
from sklearn.model_selection import KFold, cross_val_score
# Hint: KFold(n_splits=5,

# %%
results =

# %% [markdown]
# **Performance Metrics**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# 1. Confusion Matrix

# %%
predictions = model.predict(X_test)
# Hint: Use confusion_matrix( ), followed by ConfusionMatrixDisplay( )

# %% [markdown]
# 2. Classification Report

# %%
print(classification_report(y_test, predictions))

# %% [markdown]
# **Yellowbrick**'s ClassificationReport

# %%
from yellowbrick.classifier import ClassificationReport
report = ClassificationReport(model, support=True)

# %% [markdown]
# What are the results?

# %% [markdown]
# **Hyperparameter Tuning**

# %% [markdown]
# Choose a model, say Support Vector Classifier (SVC).

# %%
from sklearn.svm import SVC
model = SVC()

# %% [markdown]
# **GridSearchCV** - Exhaustive search over specified parameter values for an estimator

# %%
from sklearn.model_selection import GridSearchCV
params = dict(C=[0.001, 0.01, 0.1, 1, 10], gamma=[0.001, 0.01, 0.1, 1, 10])

# %% [markdown]
# Here we go

# %% [markdown]
# What are the parameter values that give the best score?
